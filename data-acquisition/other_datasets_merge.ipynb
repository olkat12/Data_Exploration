# %%
import pandas as pd

# %% [markdown]
# Umieścić w folderze "../data/movieLens" pobrane dane ze strony(rozpakowane)
#
# title_movies_merged.csv to ramka danych powstała w wyniku poprzedniego łączenia (to co Gabi robiła) worldwide-box z imdb movies. Polecam zapisany plik.csv w folderze "../data/merged/title_movies_merged.csv"

# %% [markdown]
# ## MOVIE LENS

# %% [markdown]
# Z tej bazy przede wszystkim będziemy potrzebować links.csv (ma id do innych też baz) oraz movies.csv (z tytułami, rokiem i gatunkiem) <br><br>
#
# W innych plikach są ratingi osobnych użytkowników oraz słowa, którymi użytkownicy określali film (ale nie zbiorczo, ale osobno dane każdego użytkownika). Jest też tabela, gdzie określana jest trafność tych określeń ludzi. Można wybrać i przypisać do każdego fimu np 5 najbardziej trafnych określeń

# %%
links = pd.read_csv("../data/movieLens/links.csv", dtype={'imdbId': str, 'tmdbId' : str})

# %%
movies = pd.read_csv("../data/movieLens/movies.csv")
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
movies = pd.merge(
    movies,
    links,
    on = 'movieId',
    suffixes=('_movies', '_links')
)

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres   imdbId tmdbId
# 0  Adventure|Animation|Children|Comedy|Fantasy  0114709    862
# 1                   Adventure|Children|Fantasy  0113497   8844
# 2                               Comedy|Romance  0113228  15602
# 3                         Comedy|Drama|Romance  0114885  31357
# 4                                       Comedy  0113041  11862
# 5                        Action|Crime|Thriller  0113277    949
# 6                               Comedy|Romance  0114319  11860
# 7                           Adventure|Children  0112302  45325
# 8                                       Action  0114576   9091
# 9                    Action|Adventure|Thriller  0113189    710

# %%
movies['year'] = movies['title'].str.extract(r'\((\d{4})\)')
movies['title'] = movies['title'].str.replace(r'\s\(\d{4}\)', '', regex=True)
movies['year'] = pd.to_numeric(movies['year'], errors='coerce')

# %%
movies = movies[['movieId', 'imdbId', 'tmdbId', 'title', 'year', 'genres']]

# %%
movies.head(10)
# Out:
#    movieId   imdbId tmdbId                        title    year  \
# 0        1  0114709    862                    Toy Story  1995.0
# 1        2  0113497   8844                      Jumanji  1995.0
# 2        3  0113228  15602             Grumpier Old Men  1995.0
# 3        4  0114885  31357            Waiting to Exhale  1995.0
# 4        5  0113041  11862  Father of the Bride Part II  1995.0
# 5        6  0113277    949                         Heat  1995.0
# 6        7  0114319  11860                      Sabrina  1995.0
# 7        8  0112302  45325                 Tom and Huck  1995.0
# 8        9  0114576   9091                 Sudden Death  1995.0
# 9       10  0113189    710                    GoldenEye  1995.0
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
title_movies_merged = pd.read_csv("../data/merged/title_movies_merged.csv")

# %%
merged = pd.merge(
    title_movies_merged,
    movies,
    left_on=['originalTitle', 'startYear'],
    right_on=['title', 'year']
)

# %%
print(title_movies_merged.shape)
print(movies.shape)
print(merged.shape)
# Out:
# (16824, 14)
# (86537, 6)
# (9790, 20)

# %% [markdown]
# Po połączeniu pliku movies z movieLens pozostało niecałe 10TYS filmów.<br>
# Tutaj jednak mamy już zapewnione id do łączenia zarówno z imdb, jak i z tmdb

# %%
merged.columns
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres_x', 'title_x',
#        'domestic_million_usd', 'overseas_million_usd', 'world_million_usd',
#        'year_x', 'movieId', 'imdbId', 'tmdbId', 'title_y', 'year_y',
#        'genres_y'],
#       dtype='object')

# %%
merged = merged[['tconst', 'imdbId', 'tmdbId', 'movieId', 'primaryTitle',
                 'isAdult', 'year_x', 'domestic_million_usd',
                 'overseas_million_usd', 'world_million_usd', 
                 'runtimeMinutes',  'genres_x', 'genres_y', ]]

# %%
merged.sort_values('year_x', ascending= False)
# Out:
#          tconst   imdbId  tmdbId  movieId  \
# 9770  tt9603212  9603212  575264   288265
# 9742  tt9185206  9185206  555285   286569
# 9179  tt5090568  5090568  667538   286899
# 9211  tt5198890  5198890  664341   281900
# 5660  tt0439572  0439572  298618   286901
# ...         ...      ...     ...      ...
# 4     tt0008329  0008329  400749   167812
# 3     tt0006333  0006333   30266    62383
# 2     tt0005393  0005393  402388   270428
# 1     tt0005059  0005059  415021   168578
# 0     tt0003471  0003471   96128   135706
#
#                                        primaryTitle  isAdult  year_x  \
# 9770  Mission: Impossible - Dead Reckoning Part One        0  2023.0
# 9742          Are You There God? It's Me, Margaret.        0  2023.0
# 9179               Transformers: Rise of the Beasts        0  2023.0
# 9211                                         Eileen        0  2023.0
# 5660                                      The Flash        0  2023.0
# ...                                             ...      ...     ...
# 4                                    Mothers of Men        0  1917.0
# 3                      20,000 Leagues Under the Sea        0  1916.0
# 2                       The Girl of the Golden West        0  1915.0
# 1                                       The Captive        0  1915.0
# 0                                  Traffic in Souls        0  1913.0
#
#       domestic_million_usd  overseas_million_usd  world_million_usd  \
# 9770                 172.1                 155.0              327.1
# 9742                  20.4                   NaN               20.4
# 9179                 157.1                   NaN              157.1
# 9211                   1.4                   NaN                1.4
# 5660                 108.1                   NaN              108.1
# ...                    ...                   ...                ...
# 4                      NaN                   0.0                0.0
# 3                      8.0                   NaN                8.0
# 2                      0.1                   NaN                0.1
# 1                      0.1                   NaN                0.1
# 0                      1.0                   NaN                1.0
#
#      runtimeMinutes                   genres_x                   genres_y
# 9770            163  Action,Adventure,Thriller  Action|Adventure|Thriller
# 9742            106        Comedy,Drama,Family               Comedy|Drama
# 9179            127    Action,Adventure,Sci-Fi    Action|Adventure|Sci-Fi
# 9211             97      Drama,Mystery,Romance              Drama|Mystery
# 5660            144   Action,Adventure,Fantasy    Action|Adventure|Sci-Fi
# ...             ...                        ...                        ...
# 4                60                      Drama                      Drama
# 3               105    Action,Adventure,Sci-Fi    Action|Adventure|Sci-Fi
# 2                45      Drama,Romance,Western            Romance|Western
# 1                50          Drama,Romance,War         (no genres listed)
# 0                88                Crime,Drama                      Drama
#
# [9790 rows x 13 columns]

# %% [markdown]
# Próbuję jeszcze połączyć z najważniejszymi słowami kluczowymi

# %%
genome_scores = pd.read_csv("../data/movieLens/genome-scores.csv")
genome_tags = pd.read_csv('../data/movieLens/genome-tags.csv')

# %%
scores_with_names = pd.merge(genome_scores, genome_tags, on='tagId')
scores_with_names = scores_with_names.sort_values(by=['movieId', 'relevance'], ascending=[True, False])
top5_tags_long = scores_with_names.groupby('movieId').head(5)
top5_tags_final = top5_tags_long.groupby('movieId')['tag'].apply(lambda x: ', '.join(x)).reset_index()
top5_tags_final.rename(columns={'tag': 'top_5_tags'}, inplace=True)

# %%
top5_tags_final.head(10)
# Out:
#    movieId                                         top_5_tags
# 0        1  toys, computer animation, pixar animation, ani...
# 1        2      adventure, children, fantasy, kids, childhood
# 2        3     good sequel, sequel, sequels, comedy, original
# 3        4  women, chick flick, girlie movie, romantic, di...
# 4        5  good sequel, sequel, sequels, midlife crisis, ...
# 5        6   crime, heist, imdb top 250, great acting, action
# 6        7  remake, romantic, romance, romantic comedy, go...
# 7        8  runaway, adapted from:book, based on a book, n...
# 8        9  action, good action, lone hero, hostage, actio...
# 9       10         007 (series), 007, bond, action, franchise

# %%
worldWide_imdb_movieLens_merged = pd.merge(
    merged,
    top5_tags_final,
    on = 'movieId'
)

# %%
worldWide_imdb_movieLens_merged.head(10)
# Out:
#       tconst   imdbId tmdbId  movieId                    primaryTitle  \
# 0  tt0006333  0006333  30266    62383    20,000 Leagues Under the Sea
# 1  tt0012532  0012532  42511     6499            Orphans of the Storm
# 2  tt0013140  0013140  35227     7288                   Foolish Wives
# 3  tt0014429  0014429  22596     8235                    Safety Last!
# 4  tt0016332  0016332  32600     3232                   Seven Chances
# 5  tt0017136  0017136     19     2010                      Metropolis
# 6  tt0018455  0018455    631     8125                         Sunrise
# 7  tt0020629  0020629    143     1927  All Quiet on the Western Front
# 8  tt0021749  0021749    901     3307                     City Lights
# 9  tt0021884  0021884   3035     2648                    Frankenstein
#
#    isAdult  year_x  domestic_million_usd  overseas_million_usd  \
# 0        0  1916.0                   8.0                   NaN
# 1        0  1921.0                   0.8                   NaN
# 2        0  1922.0                   0.4                   NaN
# 3        0  1923.0                   0.6                   NaN
# 4        0  1925.0                   0.2                   NaN
# 5        0  1927.0                   0.7                   NaN
# 6        0  1927.0                   NaN                   0.0
# 7        0  1930.0                   3.3                   NaN
# 8        0  1931.0                   3.3                   NaN
# 9        0  1931.0                  12.0                   NaN
#
#    world_million_usd runtimeMinutes                 genres_x  \
# 0                8.0            105  Action,Adventure,Sci-Fi
# 1                0.8            150    Drama,History,Romance
# 2                0.4            117           Drama,Thriller
# 3                0.6             74    Action,Comedy,Romance
# 4                0.2             56           Comedy,Romance
# 5                0.7            153             Drama,Sci-Fi
# 6                0.0             94            Drama,Romance
# 7                3.3            152                Drama,War
# 8                3.3             87     Comedy,Drama,Romance
# 9               12.0             70      Drama,Horror,Sci-Fi
#
#                   genres_y                                         top_5_tags
# 0  Action|Adventure|Sci-Fi  based on a book, original, silent, science fic...
# 1                    Drama  silent, sisters, revolution, costume drama, fr...
# 2                    Drama  black and white, silent, greed, criterion, int...
# 3    Action|Comedy|Romance  criterion, silent, imdb top 250, talky, workplace
# 4                   Comedy         silent, marriage, chase, criterion, comedy
# 5             Drama|Sci-Fi  android(s)/cyborg(s), distopia, dystopic futur...
# 6            Drama|Romance  silent, oscar (best cinematography), criterion...
# 7         Action|Drama|War  best war films, war, war movie, oscar (best pi...
# 8     Comedy|Drama|Romance  imdb top 250, masterpiece, silent, criterion, ...
# 9      Drama|Horror|Sci-Fi  mad scientist, classic, imdb top 250, horror, ...

# %%
worldWide_imdb_movieLens_merged.to_csv("../data/merged/worldWide_imdb_movieLens_merged.csv", index=False)

# %% [markdown]
# # TMDB (API)

# %% [markdown]
# Pobrałam te dane z tmdb, które łączą się po tmdbId z filmami z ramki worldWide_imdb_movieLens_merged.csv

# %%
tmdb = pd.read_csv("../data/tmdb/final_tmdb_data.csv")

# %%
print(tmdb.shape)
print(worldWide_imdb_movieLens_merged.shape)
# Out:
# (6693, 17)
# (6763, 14)
